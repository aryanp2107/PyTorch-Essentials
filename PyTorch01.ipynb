# %% [markdown]
# <a href="https://colab.research.google.com/github/aryanp2107/PyTorch-Essentials/blob/main/PyTorch01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

x = torch.empty(3)
print(x)
# Out:
# tensor([-3.3363e+32,  4.5189e-41, -3.3363e+32])

# %%
y = torch.empty(2, 3, 3)
print(y)
# Out:
# tensor([[[4.4655e-07, 4.5190e-41, 1.2845e-18],
#          [0.0000e+00, 2.7155e-21, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 0.0000e+00]],
#
#         [[0.0000e+00, 1.2867e-18, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 0.0000e+00]]])

# %%
z = torch.rand(2, 2)
print(z)
# Out:
# tensor([[0.1740, 0.3244],
#         [0.2765, 0.8435]])

# %%
print(torch.ones(2, 2))
# Out:
# tensor([[1., 1.],
#         [1., 1.]])

# %%
print(y.dtype)
# Out:
# torch.float32

# %%
x = torch.ones(2, 2, dtype=torch.float16)
print(x.size())
# Out:
# torch.Size([2, 2])

# %%
xa = torch.tensor([2.4, 2.2])
print(xa)
# Out:
# tensor([2.4000, 2.2000])

# %%
x = torch.rand(2, 2)
y = torch.rand(2, 2)
print(x)
print(y)
# Out:
# tensor([[0.0134, 0.7504],
#         [0.8886, 0.9305]])
# tensor([[0.3229, 0.4140],
#         [0.9282, 0.0636]])

# %%
z = x + y
print(z)
# Out:
# tensor([[0.3364, 1.1644],
#         [1.8167, 0.9941]])

# %%
z = torch.add(x, y)
print(z)
# Out:
# tensor([[0.3364, 1.1644],
#         [1.8167, 0.9941]])

# %%
y.add_(x)
print(y)
# Out:
# tensor([[0.3364, 1.1644],
#         [1.8167, 0.9941]])

# %%
z = x - y
# or z = torch.sub(x, y)\
print(z)
# Out:
# tensor([[-0.3229, -0.4140],
#         [-0.9282, -0.0636]])

# %%
z = torch.mul(x, y)
print(z)
# Out:
# tensor([[0.0045, 0.8737],
#         [1.6143, 0.9250]])

# %%
z = torch.div(x, y)
print(z)
# Out:
# tensor([[0.0400, 0.6444],
#         [0.4891, 0.9360]])

# %%
x = torch.rand(5, 3)
print(x)
# Out:
# tensor([[0.1900, 0.2101, 0.4634],
#         [0.2705, 0.8788, 0.6531],
#         [0.5783, 0.2427, 0.3041],
#         [0.2604, 0.5597, 0.0086],
#         [0.4438, 0.8340, 0.7513]])

# %%
#Slicing
print(x)
print(x[:, 0])
# Out:
# tensor([[0.1900, 0.2101, 0.4634],
#         [0.2705, 0.8788, 0.6531],
#         [0.5783, 0.2427, 0.3041],
#         [0.2604, 0.5597, 0.0086],
#         [0.4438, 0.8340, 0.7513]])
# tensor([0.1900, 0.2705, 0.5783, 0.2604, 0.4438])

# %%
print(x[1, :])
# Out:
# tensor([0.2705, 0.8788, 0.6531])

# %%
print(x[1, 1])
# Out:
# tensor(0.8788)

# %%
print(x[1, 1].item())
# Out:
# 0.8787717819213867

# %%
#Reshaping a tensor
x = torch.rand(4, 4)
print(x)
y = x.view(-1, 8)
print(y)
print(y.size())
# Out:
# tensor([[0.3025, 0.0777, 0.9707, 0.0212],
#         [0.7261, 0.5563, 0.7072, 0.7788],
#         [0.1326, 0.3712, 0.2006, 0.3231],
#         [0.2290, 0.0888, 0.4425, 0.2051]])
# tensor([[0.3025, 0.0777, 0.9707, 0.0212, 0.7261, 0.5563, 0.7072, 0.7788],
#         [0.1326, 0.3712, 0.2006, 0.3231, 0.2290, 0.0888, 0.4425, 0.2051]])
# torch.Size([2, 8])

# %%
# Converting from numpy to torch tensors
import numpy as np

a = torch.ones(5)
a
# Out:
# tensor([1., 1., 1., 1., 1.])

# %%
b = a.numpy()
print(b)
# Out:
# [1. 1. 1. 1. 1.]

# %%
print(type(b))
# Out:
# <class 'numpy.ndarray'>

# %%
a.add_(1)
print(a)
# Out:
# tensor([2., 2., 2., 2., 2.])

# %%
print(b)
#This will add to both of them coz they point to the same memory location
# Out:
# [2. 2. 2. 2. 2.]

# %%
a = np.ones(5)
print(a)
b = torch.from_numpy(a)
print(b)
print(type(b))
# Out:
# [1. 1. 1. 1. 1.]
# tensor([1., 1., 1., 1., 1.], dtype=torch.float64)
# <class 'torch.Tensor'>

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
    x = torch.ones(5, device=device)
    y = torch.ones(5)
    y = y.to(device)
    z = x + y
    print(z)

# %%
z
# Out:
# tensor([[0.0400, 0.6444],
#         [0.4891, 0.9360]])

# %% [markdown]
# Gradient Calculation with Autograd

# %%
import torch

x = torch.randn(3, requires_grad=True)
print(x)

y = x + 2
print(y)
# Out:
# tensor([2.2979, 1.1330, 0.5632], requires_grad=True)
# tensor([4.2979, 3.1330, 2.5632], grad_fn=<AddBackward0>)

# %%
z = y*y*2
print(z)
# Out:
# tensor([36.9443, 19.6312, 13.1395], grad_fn=<MulBackward0>)

# %%
z = z.mean()
print(z)

z.backward()
print(x.grad)
# Out:
# tensor(23.2384, grad_fn=<MeanBackward0>)
# tensor([5.7306, 4.1773, 3.4175])

# %%
x = torch.randn(3, requires_grad=False)
print(x)
#We must specify if we need parrarel computation of gradient descent
# Out:
# tensor([0.4083, 0.2883, 0.4989])

# %%
x = torch.randn(3, requires_grad=True)

#x.requires_grad_(False)
#x.detach()
# with torch.no_grad()

x.requires_grad_(False)
print(x)
# Out:
# tensor([0.2644, 0.1310, 1.0282])

# %%
y = x.detach()
y
# Out:
# tensor([0.2644, 0.1310, 1.0282])

# %%
weights = torch.ones(4, requires_grad=True)
for epoch in range(1):
  model_output = (weights*3).sum()
  model_output.backward()
  print(weights.grad)
# Out:
# tensor([3., 3., 3., 3.])

# %%
weights = torch.ones(4, requires_grad=True)
for epoch in range(2):
  model_output = (weights*3).sum()
  model_output.backward()
  print(weights.grad)
# Out:
# tensor([3., 3., 3., 3.])
# tensor([6., 6., 6., 6.])

# %%
weights = torch.ones(4, requires_grad=True)
for epoch in range(3):
  model_output = (weights*3).sum()
  model_output.backward()
  print(weights.grad)
# Out:
# tensor([3., 3., 3., 3.])
# tensor([6., 6., 6., 6.])
# tensor([9., 9., 9., 9.])

# %%
weights = torch.ones(4, requires_grad=True)
for epoch in range(3):
  model_output = (weights*3).sum()
  model_output.backward()
  print(weights.grad)
  weights.grad.zero_()
# Out:
# tensor([3., 3., 3., 3.])
# tensor([3., 3., 3., 3.])
# tensor([3., 3., 3., 3.])

# %%
weights = torch.ones(4, requires_grad=True)
optimizer = torch.optim.SGD([weights], lr=0.01)
optimizer.step()
optimizer.zero_grad()
